# %%
stored_password = "My_password@123"

user_input = input("Enter your password: ")

if user_input == stored_password:
    print("Password Matched")
else:
    print("Wrong Password")
# Out:
# Enter your password: 123
# Wrong Password
