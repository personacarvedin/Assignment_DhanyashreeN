# %%
import pandas as pd

# Create dataset
data = {
    "Study_Hours": [1, 2, 3, 4, 5, 6, 7, 8],
    "Marks": [35, 40, 50, 55, 65, 70, 80, 90]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Study_Hours  Marks
# 0            1     35
# 1            2     40
# 2            3     50
# 3            4     55
# 4            5     65
# 5            6     70
# 6            7     80
# 7            8     90

# %%
df.to_csv("study_hours_marks.csv", index=False)

# %%
X = df[["Study_Hours"]]   # Feature
y = df["Marks"]           # Label

print("Feature:")
print(X.head())

print("\nLabel:")
print(y.head())
# Out:
# Feature:
#    Study_Hours
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#
# Label:
# 0    35
# 1    40
# 2    50
# 3    55
# 4    65
# Name: Marks, dtype: int64

# %%
df.corr()
# Out:
#              Study_Hours     Marks
# Study_Hours     1.000000  0.996464
# Marks           0.996464  1.000000
