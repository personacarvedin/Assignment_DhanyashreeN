# %%
import time
import numpy as np

# Create 1 million numbers
size = 1_000_000

# Python list
py_list = list(range(size))

# NumPy array
np_array = np.arange(size)

start = time.time()

py_result = [x * 2 for x in py_list]

end = time.time()
print("Python List Time:", end - start)

start = time.time()

np_result = np_array * 2

end = time.time()
print("NumPy Array Time:", end - start)
# Out:
# Python List Time: 0.05105853080749512
# NumPy Array Time: 0.0036885738372802734
