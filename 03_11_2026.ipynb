# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

data = pd.DataFrame({
    "Annual Income": [15,16,17,18,19,20,60,62,63,65,70,72,75,78,80],
    "Spending Score": [39,81,6,77,40,76,55,54,60,61,70,69,80,85,90]
})

X = data[["Annual Income","Spending Score"]]

kmeans = KMeans(n_clusters=3, random_state=42)
data["Cluster"] = kmeans.fit_predict(X)

plt.scatter(data["Annual Income"], data["Spending Score"], c=data["Cluster"])
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1])
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.show()

print(data)
# Out:
#     Annual Income  Spending Score  Cluster
# 0              15              39        2
# 1              16              81        0
# 2              17               6        2
# 3              18              77        0
# 4              19              40        2
# 5              20              76        0
# 6              60              55        1
# 7              62              54        1
# 8              63              60        1
# 9              65              61        1
# 10             70              70        1
# 11             72              69        1
# 12             75              80        1
# 13             78              85        1
# 14             80              90        1
